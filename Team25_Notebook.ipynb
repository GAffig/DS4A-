# %% [markdown]
# <a href="https://colab.research.google.com/github/GAffig/DS4A-/blob/main/Team25_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#pip install  pandasql
#from pandasql import sqldf

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61e0a606-121b-4f9a-87ec-2212b165ba9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61e0a606-121b-4f9a-87ec-2212b165ba9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
inc = pd.read_csv(io.BytesIO(uploaded['mass_killing_incidents_public.csv']))

# %%
vic = df1
vic.head()
# Out:
# 1

# %%
#vic[vic['incident_id'].isna()]
#vic = vic.dropna(subset=['incident_id'])
#vic.incident_id= vic.incident_id.astype(int)

vic.head()
# Out:
#    incident_id  victim_id   age             race     sex vorelationship  \
# 0            1          1  25.0  Hispanic/Latino    Male   Undetermined
# 1            1          2  30.0  Hispanic/Latino    Male   Undetermined
# 2            1          3  30.0  Hispanic/Latino    Male   Undetermined
# 3            1          4  32.0  Hispanic/Latino    Male   Undetermined
# 4            2          5  30.0            White  Female       Neighbor
#
#    incident
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       2.0

# %%
vic.drop()

# %%
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
inc.head()
# Out:
#      incident_id        date              city state  num_offenders  \
# 371            1  2010-09-02           Chicago    IL              2
# 369            2  2010-09-11           Jackson    KY              1
# 370            3  2010-09-04      Lake Charles    LA              1
# 367            4  2010-09-28            Boston    MA              3
# 372            5  2010-08-28  Lake Havasu City    AZ              1
#
#      num_victims_killed  num_victims_injured  firstcod secondcod    type  \
# 371                   4                  0.0  Shooting       NaN  Felony
# 369                   5                  0.0  Shooting       NaN  Family
# 370                   4                  0.0  Shooting       NaN   Other
# 367                   4                  1.0  Shooting       NaN  Felony
# 372                   5                  1.0  Shooting       NaN  Family
#
#              situation_type            location_type   location   longitude  \
# ...

# %%
query = """ SELECT st.Students, st.Gender, st.Email, st.Age, tat.Department
            FROM students_df st INNER JOIN teaching_assistant_df tat 
            ON st.Email = tat.Email;
            """

result = sqldf(query)
result
# Out:
# 371    False
# 369    False
# 370    False
# 367    False
# 372    False
#        ...
# 4      False
# 3      False
# 2      False
# 1      False
# 0      False
# Name: incident_id, Length: 523, dtype: bool

# %%
query = """ SELECT *
            FROM vic INNER JOIN inc 
            ON vic.incident_id = inc.incident_id;
            """

result = sqldf(query)

# %%
result.head(10)
result.firstcod.unique()
# Out:
# array(['Shooting', 'Stabbing', 'Smoke inhalation & burns', 'Blunt force',
#        'Strangulation', 'Vehicle crash', 'Pushing/Jumping', 'Drowning',
#        'Unknown', 'Asphyxiation'], dtype=object)

# %%
result.state = result.state.astype('category')

# %%
result.state.value_counts()
# Out:
# CA    291
# TX    280
# FL    183
# IL    145
# OH    119
# NY    106
# VA    103
# GA     81
# NV     80
# PA     76
# WA     75
# AZ     75
# MI     70
# NC     64
# SC     63
# MO     63
# WI     61
# IN     61
# AL     57
# LA     56
# TN     53
# CO     51
# OK     47
# CT     40
# MD     38
# OR     35
# KS     35
# MS     32
# NJ     28
# MA     28
# WV     26
# KY     26
# DC     24
# NM     19
# MN     18
# AR     17
# NE     16
# UT     13
# ND     12
# IA     10
# AK      8
# ID      8
# DE      8
# WY      8
# SD      5
# MT      4
# VT      4
# ME      4
# Name: state, dtype: int64

# %% [markdown]
# ## FOCUS B4 SATURDAY
# * life expectancy at birth dataset by state and standard error
# * grouped by sex
# * we neeed 2016 and 2017
#
# ### States
# * CA    291
# * TX    280
# * FL    183
# * IL    145
# * OH    119
